# %%
import pandas as pd

# %%
df=pd.read_csv('Past In and Out.csv')

# %%
df
# Out:
#            REF_ID            IN_TIME           VALIDITY      CON_NUM  \
# 0        EFS31075  12-11-22 01:29:54  15-11-22 01:29:54  QSNE0761953
# 1        EFS31294  22-11-22 13:40:39  25-11-22 13:40:39  OFXS8497438
# 2        EFS31695  04-12-22 17:13:02  07-12-22 17:13:02  DRVO4626646
# 3        EFS31708  05-12-22 16:08:52  08-12-22 16:08:52  AYVO2980897
# 4        EFS31708  05-12-22 16:08:52  08-12-22 16:08:52  JJRB9424765
# ...           ...                ...                ...          ...
# 24812  IGOJO16263  25-04-23 16:04:24  28-04-23 16:04:24  JKLM2839432
# 24813  IGOJO16263  25-04-23 16:04:24  28-04-23 16:04:24  XGFQ4284893
# 24814  IGOJO16263  25-04-23 16:04:24  28-04-23 16:04:24  QKOM5097519
# 24815    EFS36469  25-04-23 16:41:47  28-04-23 16:41:47  EPWV7602649
# 24816  IGOJO16269  25-04-23 16:42:26  28-04-23 16:42:26  DGGR1664955
#
#        CON_SIZE STATUS           OUT_TIME
# 0          40.0      E  07-02-23 01:23:12
# 1          40.0      E  02-02-23 19:33:42
# 2          20.0      E  10-02-23 05:09:09
# 3          20.0      E  28-02-23 08:22:08
# 4          20.0      E  17-04-23 17:23:16
# ...         ...    ...                ...
# 24812      40.0    NaN  26-04-23 18:05:29
# 24813      40.0    NaN  26-04-23 19:16:55
# 24814      40.0    NaN  27-04-23 00:11:08
# 24815      40.0      E  26-04-23 05:50:02
# 24816      40.0      L  25-04-23 23:07:49
#
# [24817 rows x 7 columns]

# %%
from datetime import datetime
def Milli(X):
    given_date_time = X
    epoch = datetime(1970, 1, 1)
    time_difference = given_date_time - epoch
    total_seconds = time_difference.total_seconds()
    milliseconds = int(total_seconds * 1000)
    return milliseconds

def Date_Time(X):
    seconds = X / 1000
    date_time = datetime.fromtimestamp(seconds)
    date_time1= date_time.strftime('%Y-%m-%d %H:%M:%S')
    return date_time1

# %%
from datetime import datetime
import pandas as pd
IN_Time=[]
OUT_Time=[]
for i in range(df.shape[0]):
    x1 = datetime.strptime(df['IN_TIME'][i], '%d-%m-%y %H:%M:%S')
    x1m = Milli(x1)
    IN_Time.append(x1m)
    y1 = datetime.strptime(df['OUT_TIME'][i], '%d-%m-%y %H:%M:%S')
    y1m = Milli(y1)
    IN_Time.append(x1m)
    OUT_Time.append(y1m)
In = pd.DataFrame(IN_Time)
Out = pd.DataFrame(OUT_Time)

# %%
df.drop(columns='REF_ID',axis=1,inplace=True)
df.drop(columns='VALIDITY',axis=1,inplace=True)
df.drop(columns='CON_NUM',axis=1,inplace=True)
df.drop(columns='IN_TIME',axis=1,inplace=True)
df.drop(columns='OUT_TIME',axis=1,inplace=True)

# %%
df['In_time'] = In
df['Out_time'] = Out

# %%
df.isna().sum()
# Out:
# CON_SIZE      6
# STATUS      280
# In_time       0
# Out_time      0
# dtype: int64

# %%
df
# Out:
#        CON_SIZE STATUS        In_time       Out_time
# 0          40.0      E  1668216594000  1675732992000
# 1          40.0      E  1668216594000  1675366422000
# 2          20.0      E  1669124439000  1676005749000
# 3          20.0      E  1669124439000  1677572528000
# 4          20.0      E  1670173982000  1681752196000
# ...         ...    ...            ...            ...
# 24812      40.0    NaN  1678738917000  1682532329000
# 24813      40.0    NaN  1678738917000  1682536615000
# 24814      40.0    NaN  1678738917000  1682554268000
# 24815      40.0      E  1678738917000  1682488202000
# 24816      40.0      L  1678740230000  1682464069000
#
# [24817 rows x 4 columns]

# %%
df.dropna(axis=0,inplace=True)

# %%
df.isna().sum()
# Out:
# CON_SIZE    0
# STATUS      0
# In_time     0
# Out_time    0
# dtype: int64

# %%
df1=pd.get_dummies(data=df['STATUS'],drop_first=True)
df1
df['L']=df1

# %%
df.drop(['STATUS'], axis=1,inplace=True)

# %%
x=df.drop('Out_time',axis=1)
y=df['Out_time']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (19624, 3)
# (4907, 3)
# (19624,)
# (4907,)

# %%
import numpy 
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)

print(lr.coef_)
print(lr.intercept_)
# Out:
# [2.28387833e+06 1.84422256e+00 1.41905305e+08]
# -1413667446568.8462

# %%
y_pred=lr.predict(x_test)
print(y_pred)
print(y_test)
# Out:
# [1.68188935e+12 1.68154721e+12 1.68200380e+12 ... 1.67710890e+12
#  1.67731105e+12 1.67692288e+12]
# 18953    1681916947000
# 23024    1682434910000
# 19636    1681999152000
# 23327    1682499446000
# 9720     1678706164000
#              ...
# 3930     1675900021000
# 23376    1682598769000
# 7254     1677150352000
# 5745     1676963220000
# 7260     1677088618000
# Name: Out_time, Length: 4907, dtype: int64

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_pred,y_test)
mse
# Out:
# 1.2671509950390574e+18

# %%
df=pd.read_csv('Insert data.csv')
x = df['IN_TIME'][0]
x1 = datetime.strptime(x, '%d-%m-%y %H:%M:%S')
x1m=Milli(x1)
Out=[[40,x1m,1]]
Outtime = Date_Time(int(lr.predict(Out)))
print(Outtime)
# Out:
# 2021-06-24 08:27:58
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df
# Out:
#            REF_ID            IN_TIME           VALIDITY      CON_NUM  \
# 0        EFS31075  12-11-22 01:29:54  15-11-22 01:29:54  QSNE0761953
# 1        EFS31294  22-11-22 13:40:39  25-11-22 13:40:39  OFXS8497438
# 2        EFS31695  04-12-22 17:13:02  07-12-22 17:13:02  DRVO4626646
# 3        EFS31708  05-12-22 16:08:52  08-12-22 16:08:52  AYVO2980897
# 4        EFS31708  05-12-22 16:08:52  08-12-22 16:08:52  JJRB9424765
# ...           ...                ...                ...          ...
# 24812  IGOJO16263  25-04-23 16:04:24  28-04-23 16:04:24  JKLM2839432
# 24813  IGOJO16263  25-04-23 16:04:24  28-04-23 16:04:24  XGFQ4284893
# 24814  IGOJO16263  25-04-23 16:04:24  28-04-23 16:04:24  QKOM5097519
# 24815    EFS36469  25-04-23 16:41:47  28-04-23 16:41:47  EPWV7602649
# 24816  IGOJO16269  25-04-23 16:42:26  28-04-23 16:42:26  DGGR1664955
#
#        CON_SIZE STATUS           OUT_TIME
# 0          40.0      E  07-02-23 01:23:12
# 1          40.0      E  02-02-23 19:33:42
# 2          20.0      E  10-02-23 05:09:09
# 3          20.0      E  28-02-23 08:22:08
# 4          20.0      E  17-04-23 17:23:16
# ...         ...    ...                ...
# 24812      40.0    NaN  26-04-23 18:05:29
# 24813      40.0    NaN  26-04-23 19:16:55
# 24814      40.0    NaN  27-04-23 00:11:08
# 24815      40.0      E  26-04-23 05:50:02
# 24816      40.0      L  25-04-23 23:07:49
#
# [24817 rows x 7 columns]

# %%
# Out:
# Date and Time: 2022-09-14 09:38:10
