# %%
import pandas as pd

# %%
df=pd.read_csv('Past In and Out.csv')

# %%
from datetime import datetime
def Milli(X):
    given_date_time = X
    epoch = datetime(1970, 1, 1)
    time_difference = given_date_time - epoch
    total_seconds = time_difference.total_seconds()
    milliseconds = int(total_seconds * 1000)
    return milliseconds

def Date_Time(X):
    seconds = X / 1000
    date_time = datetime.fromtimestamp(seconds)
    date_time1= date_time.strftime('%d-%m-%y %H:%M:%S')
    return date_time1

# %%
from datetime import datetime
import pandas as pd
IN_Time=[]
OUT_Time=[]

for i in range(df.shape[0]):
    x1 = datetime.strptime(df['IN_TIME'][i], '%d-%m-%y %H:%M:%S')
    x1m = Milli(x1)
    IN_Time.append(x1m)
    y1 = datetime.strptime(df['OUT_TIME'][i], '%d-%m-%y %H:%M:%S')
    y1m = Milli(y1)
    IN_Time.append(x1m)
    OUT_Time.append(y1m)
In = pd.DataFrame(IN_Time)
Out = pd.DataFrame(OUT_Time)

# %%
df.drop(columns='REF_ID',axis=1,inplace=True)
df.drop(columns='VALIDITY',axis=1,inplace=True)
df.drop(columns='CON_NUM',axis=1,inplace=True)
df.drop(columns='IN_TIME',axis=1,inplace=True)
df.drop(columns='OUT_TIME',axis=1,inplace=True)

# %%
df['In_time'] = In
df['Out_time'] = Out

# %%
df.dropna(axis=0,inplace=True)

# %%
df.reset_index(inplace=True)

# %%
df1=pd.get_dummies(data=df['STATUS'],drop_first=True)
df['L']=df1

# %%
df.drop(columns='STATUS',axis=1,inplace=True)
df.drop(columns='index',axis=1,inplace=True)

# %%
Time_diff = []
for i in range(df.shape[0]):
    Time_diff.append(df['Out_time'][i]-df['In_time'][i])
    
df['Time_Diff'] = Time_diff
def find_outliers(df,col):
    q1=df[col].quantile(0.25)
    q3=df[col].quantile(0.75)
    IQR=q3-q1
    lv=q1-1.5*IQR
    hv=q3+1.5*IQR
    df=df[(df[col]<=hv) | (df[col]>=lv)]
    return df
find_outliers(df,'Time_Diff')
# Out:
#        CON_SIZE        In_time       Out_time  L    Time_Diff
# 0          40.0  1668216594000  1675732992000  0   7516398000
# 1          40.0  1668216594000  1675366422000  0   7149828000
# 2          20.0  1669124439000  1676005749000  0   6881310000
# 3          20.0  1669124439000  1677572528000  0   8448089000
# 4          20.0  1670173982000  1681752196000  0  11578214000
# ...         ...            ...            ... ..          ...
# 24524      40.0  1678738917000  1682467275000  1   3728358000
# 24525      40.0  1678738917000  1682478340000  1   3739423000
# 24526      20.0  1678738917000  1682474490000  1   3735573000
# 24527      40.0  1678740230000  1682488202000  0   3747972000
# 24528      40.0  1678740230000  1682464069000  1   3723839000
#
# [24529 rows x 5 columns]

# %%
df.drop(columns='Time_Diff',axis=1,inplace=True)

# %%
x=df.drop('Out_time',axis=1)
y=df['Out_time']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (19623, 3)
# (4906, 3)
# (19623,)
# (4906,)

# %%
import numpy 
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
lr.fit(x_train,y_train)

print(lr.coef_)
print(lr.intercept_)
# Out:
# [2.58619498e+06 1.84151937e+00 1.46778791e+08]
# -1409148897269.0027

# %%
y_pred=lr.predict(x_test)
print(y_pred)
print(y_test)
# Out:
# [1.68175294e+12 1.68044246e+12 1.68091108e+12 ... 1.68220033e+12
#  1.67711545e+12 1.67787852e+12]
# 20997    1681911443000
# 12655    1679226166000
# 19424    1681999096000
# 16029    1681056131000
# 9602     1678633379000
#              ...
# 3244     1675876990000
# 3877     1676609170000
# 23117    1682557658000
# 7149     1677308338000
# 5655     1677050680000
# Name: Out_time, Length: 4906, dtype: int64

# %%
from sklearn.metrics import mean_squared_error
mse=mean_squared_error(y_pred,y_test)
mse
# Out:
# 1.257241066359832e+18

# %%
df=pd.read_csv('Insert data.csv')
x = df['IN_TIME'][0]
x1 = datetime.strptime(x, '%d-%m-%y %H:%M:%S')
x1m=Milli(x1)
Out=[[40,x1m,1]]
x1=lr.predict(Out)
Outtime = datetime.strptime(Date_Time(int(x1)),'%d-%m-%y %H:%M:%S')
print(Outtime)
# Out:
# 2021-06-25 07:24:57
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
x1 = datetime.strptime(Date_Time(int(x1)),'%d-%m-%y %H:%M:%S')

# %%
print(Outtime==Outtime)
# Out:
# True

# %%
df = pd.read_csv('Insert data.csv')

# %%
df
# Out:
#       ID            IN_TIME                 REF_ID      CON_NUM  CON_SIZE  \
# 0    322  14-03-22 15:46:44               ALO11887  SPRE0057868        20
# 1    322  14-03-22 15:46:44               ALO11887  ANKJ1447873        20
# 2    322  14-03-22 15:46:44               ALO11887  ACLU3053768        20
# 3    326  17-04-22 04:41:42              DP02MAR10  BUDE0578181        40
# 4    326  17-04-22 04:41:42              DP02MAR10  UPDU1678037        20
# ..   ...                ...                    ...          ...       ...
# 345  554  20-03-22 14:48:13  ALO11980-98997-330244  IVIP5581378        20
# 346  555  20-03-22 14:48:13  ALO11980-98998-330245  XEFF1829672        20
# 347  556  20-03-22 14:48:13  ALO11980-98999-330246  BFIU2996554        20
# 348  557  20-03-22 14:48:13  ALO11980-99000-330247  RDCW7179253        20
# 349  558  20-03-22 14:48:13  ALO11980-99001-330248  NUDE0749531        20
#
#     STATUS
# 0        L
# 1        L
# 2        L
# 3        L
# 4        E
# ..     ...
# 345      L
# 346      L
# 347      L
# 348      L
# 349      L
#
# [350 rows x 6 columns]

# %%
OutTime=[]
s=0
for i in range(df.shape[0]):
    if df['STATUS'][i] == 'L':
        s=1
    else:
        s=0
    pre = Predict_Out_Time(df['IN_TIME'],df['CON_SIZE'],s)
    OutTime.append(pre)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_33964\3749222033.py in <module>
#       6     else:
#       7         s=0
# ----> 8     pre = Predict_Out_Time(df['IN_TIME'],df['CON_SIZE'],s)
#       9     Outtime.append(pre)
#
# NameError: name 'Predict_Out_Time' is not defined

# %%
type(df['IN_TIME'][0])
# Out:
# str

# %%
import numpy
import pandas as pd
from datetime import datetime
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split


def Predict_Out_Time(Time,size,state):
    df = pd.read_csv('Past In and Out.csv')

    def Milli(X):
        given_date_time = X
        epoch = datetime(1970, 1, 1)
        time_difference = given_date_time - epoch
        total_seconds = time_difference.total_seconds()
        milliseconds = int(total_seconds * 1000)
        return milliseconds

    def Date_Time(X):
        seconds = X / 1000
        date_time = datetime.fromtimestamp(seconds)
        date_time1= date_time.strftime('%d-%m-%y %H:%M:%S')
        return date_time1

    IN_Time = []
    OUT_Time = []
    for i in range(df.shape[0]):
        x1 = datetime.strptime(df['IN_TIME'][i], '%d-%m-%y %H:%M:%S')
        x1m = Milli(x1)
        IN_Time.append(x1m)
        y1 = datetime.strptime(df['OUT_TIME'][i], '%d-%m-%y %H:%M:%S')
        y1m = Milli(y1)
        IN_Time.append(x1m)
        OUT_Time.append(y1m)
    In = pd.DataFrame(IN_Time)
    Out = pd.DataFrame(OUT_Time)
    df.drop(columns='REF_ID', axis=1, inplace=True)
    df.drop(columns='VALIDITY', axis=1, inplace=True)
    df.drop(columns='CON_NUM', axis=1, inplace=True)
    df.drop(columns='IN_TIME', axis=1, inplace=True)
    df.drop(columns='OUT_TIME', axis=1, inplace=True)
    df['In_time'] = In
    df['Out_time'] = Out
    df.dropna(axis=0, inplace=True)
    df.reset_index(inplace=True)
    df1 = pd.get_dummies(data=df['STATUS'], drop_first=True)
    df['L'] = df1
    df.drop(['STATUS'], axis=1, inplace=True)
    df.drop(columns='index',axis=1,inplace=True)
    Time_diff = []
    for i in range(df.shape[0]):
        Time_diff.append(df['Out_time'][i]-df['In_time'][i])
        
    df['Time_Diff'] = Time_diff
    def find_outliers(df,col):
        q1=df[col].quantile(0.25)
        q3=df[col].quantile(0.75)
        IQR=q3-q1
        lv=q1-1.5*IQR
        hv=q3+1.5*IQR
        df=df[(df[col]<=hv) | (df[col]>=lv)]
        return df
    find_outliers(df,'Time_Diff')
    df.drop(columns='Time_Diff',axis=1,inplace=True)
    x = df.drop('Out_time', axis=1)
    y = df['Out_time']
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=1)
    # print(x_train.shape)
    # print(x_test.shape)
    # print(y_train.shape)
    # print(y_test.shape)
    lr = LinearRegression()
    lr.fit(x_train, y_train)
    # print(lr.coef_)
    # print(lr.intercept_)
    y_pred = lr.predict(x_test)
    # print(y_pred)
    # print(y_test)
    mse = mean_squared_error(y_pred, y_test)
    # mse
    df = pd.read_csv('Insert data.csv')
    x = Time
    x1 = datetime.strptime(x, '%d-%m-%y %H:%M:%S')
    x1m = Milli(x1)
    Out = [[size, x1m, state]]
    x1=lr.predict(Out)
    Outtime = datetime.strptime(Date_Time(int(x1)),'%d-%m-%y %H:%M:%S')
    return Outtime


pre = Predict_Out_Time('14-03-22 15:46:44',20,1)
print(pre)

df = pd.read_csv('Insert data.csv')
OutTime=[]
s=0
for i in range(df.shape[0]):
    if df['STATUS'][i] == 'L':
        s=1
    else:
        s=0
    pre = Predict_Out_Time(df['IN_TIME'][i],df['CON_SIZE'][i],s)
    OutTime.append(pre)
print(OutTime)
df['Out_Time'] = OutTime
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# 2021-06-24 17:02:53
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# ...
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# [datetime.datetime(2021, 6, 24, 17, 2, 53), datetime.datetime(2021, 6, 24, 17, 2, 53), datetime.datetime(2021, 6, 24, 17, 2, 53), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 23, 18, 32, 42), datetime.datetime(2021, 8, 25, 11, 19), datetime.datetime(2021, 8, 25, 11, 19), datetime.datetime(2021, 8, 24, 8, 54, 45), datetime.datetime(2021, 8, 24, 8, 54, 45), datetime.datetime(2021, 8, 24, 8, 54, 45), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 24, 8, 54, 45), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 24, 8, 54, 45), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 26, 1, 41, 4), datetime.datetime(2021, 8, 24, 8, 54, 45), datetime.datetime(2021, 6, 27, 0, 51, 41), datetime.datetime(2021, 6, 27, 0, 51, 41), datetime.datetime(2021, 6, 27, 0, 51, 41), datetime.datetime(2021, 6, 27, 0, 51, 41), datetime.datetime(2021, 6, 27, 1, 2, 24), datetime.datetime(2021, 6, 27, 1, 43, 55), datetime.datetime(2021, 6, 27, 2, 22, 48), datetime.datetime(2021, 6, 24, 20, 25, 10), datetime.datetime(2021, 6, 24, 20, 49, 7), datetime.datetime(2021, 6, 27, 8, 45, 41), datetime.datetime(2021, 6, 27, 8, 45, 41), datetime.datetime(2021, 6, 27, 11, 53, 4), datetime.datetime(2021, 6, 27, 11, 53, 4), datetime.datetime(2021, 6, 27, 22, 36, 18), datetime.datetime(2021, 6, 27, 22, 54, 30), datetime.datetime(2021, 6, 28, 0, 6, 23), datetime.datetime(2021, 6, 29, 21, 36, 8), datetime.datetime(2021, 6, 29, 21, 36, 8), datetime.datetime(2021, 6, 29, 21, 57, 8), datetime.datetime(2021, 6, 29, 22, 40, 20), datetime.datetime(2021, 6, 29, 22, 45, 41), datetime.datetime(2021, 6, 29, 22, 57, 50), datetime.datetime(2021, 6, 29, 23, 10, 36), datetime.datetime(2021, 6, 29, 23, 56, 46), datetime.datetime(2021, 6, 29, 23, 56, 46), datetime.datetime(2021, 6, 30, 4, 53, 27), datetime.datetime(2021, 6, 30, 20, 33, 28), datetime.datetime(2021, 6, 30, 20, 33, 28), datetime.datetime(2021, 6, 30, 20, 33, 28), datetime.datetime(2021, 7, 1, 16, 12, 28), datetime.datetime(2021, 7, 1, 16, 16, 15), datetime.datetime(2021, 7, 1, 1, 59, 13), datetime.datetime(2021, 7, 1, 3, 7, 12), datetime.datetime(2021, 7, 2, 1, 45, 11), datetime.datetime(2021, 7, 2, 1, 45, 11), datetime.datetime(2021, 7, 2, 4, 16, 11), datetime.datetime(2021, 6, 30, 13, 5, 42), datetime.datetime(2021, 6, 26, 20, 8, 38), datetime.datetime(2021, 6, 24, 13, 0, 16), datetime.datetime(2021, 6, 24, 13, 0, 16), datetime.datetime(2021, 6, 24, 13, 0, 16), datetime.datetime(2021, 6, 24, 13, 0, 16), datetime.datetime(2021, 6, 24, 13, 0, 16), datetime.datetime(2021, 6, 24, 13, 0, 16), datetime.datetime(2021, 6, 24, 13, 0, 16), dat ...
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
df
# Out:
#       ID            IN_TIME                 REF_ID      CON_NUM  CON_SIZE  \
# 0    322  14-03-22 15:46:44               ALO11887  SPRE0057868        20
# 1    322  14-03-22 15:46:44               ALO11887  ANKJ1447873        20
# 2    322  14-03-22 15:46:44               ALO11887  ACLU3053768        20
# 3    326  17-04-22 04:41:42              DP02MAR10  BUDE0578181        40
# 4    326  17-04-22 04:41:42              DP02MAR10  UPDU1678037        20
# ..   ...                ...                    ...          ...       ...
# 345  554  20-03-22 14:48:13  ALO11980-98997-330244  IVIP5581378        20
# 346  555  20-03-22 14:48:13  ALO11980-98998-330245  XEFF1829672        20
# 347  556  20-03-22 14:48:13  ALO11980-98999-330246  BFIU2996554        20
# 348  557  20-03-22 14:48:13  ALO11980-99000-330247  RDCW7179253        20
# 349  558  20-03-22 14:48:13  ALO11980-99001-330248  NUDE0749531        20
#
#     STATUS            Out_Time
# 0        L 2021-06-24 17:02:53
# 1        L 2021-06-24 17:02:53
# 2        L 2021-06-24 17:02:53
# 3        L 2021-08-26 01:41:04
# 4        E 2021-08-23 18:32:42
# ..     ...                 ...
# 345      L 2021-07-05 16:25:51
# 346      L 2021-07-05 16:25:51
# 347      L 2021-07-05 16:25:51
# 348      L 2021-07-05 16:25:51
# 349      L 2021-07-05 16:25:51
#
# [350 rows x 7 columns]

# %%
# df.to_csv('Predicted_Data')

# %%
df = pd.read_csv('Predicted_Data.csv')

# %%
df
# Out:
#      Unnamed: 0   ID            IN_TIME                 REF_ID      CON_NUM
# 0             0  322  14-03-22 15:46:44               ALO11887  SPRE0057868  \
# 1             1  322  14-03-22 15:46:44               ALO11887  ANKJ1447873
# 2             2  322  14-03-22 15:46:44               ALO11887  ACLU3053768
# 3             3  326  17-04-22 04:41:42              DP02MAR10  BUDE0578181
# 4             4  326  17-04-22 04:41:42              DP02MAR10  UPDU1678037
# ..          ...  ...                ...                    ...          ...
# 345         345  554  20-03-22 14:48:13  ALO11980-98997-330244  IVIP5581378
# 346         346  555  20-03-22 14:48:13  ALO11980-98998-330245  XEFF1829672
# 347         347  556  20-03-22 14:48:13  ALO11980-98999-330246  BFIU2996554
# 348         348  557  20-03-22 14:48:13  ALO11980-99000-330247  RDCW7179253
# 349         349  558  20-03-22 14:48:13  ALO11980-99001-330248  NUDE0749531
#
#      CON_SIZE STATUS             Out_Time
# 0          20      L  2021-06-24 17:02:53
# 1          20      L  2021-06-24 17:02:53
# 2          20      L  2021-06-24 17:02:53
# 3          40      L  2021-08-26 01:41:04
# 4          20      E  2021-08-23 18:32:42
# ..        ...    ...                  ...
# 345        20      L  2021-07-05 16:25:51
# 346        20      L  2021-07-05 16:25:51
# 347        20      L  2021-07-05 16:25:51
# 348        20      L  2021-07-05 16:25:51
# 349        20      L  2021-07-05 16:25:51
#
# [350 rows x 8 columns]

# %%
print(df['IN_TIME'][0]>df['Out_Time'][0])
# Out:
# False

# %%
print(type(df['IN_TIME'][0]))
type(df['Out_Time'][0])
# Out:
# <class 'str'>
# str

# %%
x1 = 
print(x1)
# Out:
# 2015-03-14 15:46:44

# %%
type(x1)
# Out:
# datetime.datetime

# %%
print(x1)
# Out:
# 2022-03-14 15:46:44

# %%
import numpy as np
area={}
from datetime import datetime

def Milli(X):
    given_date_time = X
    epoch = datetime(1970, 1, 1)
    time_difference = given_date_time - epoch
    total_seconds = time_difference.total_seconds()
    milliseconds = int(total_seconds * 1000)
    return milliseconds
def Date_Time(X):
    seconds = X / 1000
    date_time = datetime.fromtimestamp(seconds)
    date_time1= date_time.strftime('%d-%m-%Y %H:%M:%S')
    return date_time1
# /////////////////////////////grid created//////////////////////////////////////////////////

def create_grid(are,lev,col,row):
    global area
    if(are not in area):
        shape = (lev, col, row)
        #       val=how many days for exporting container       
        myList = [[[{'val':0,'id':'','below_container_export_days':0,'container_size':0} for r in range(row)] for c in range(col)]for l in range(lev)]   
        area[are] = {'shape':myList,'container_type':' ','size':row*col*lev,'full':False}
        print('grid created!')
    else:
        print('Area already present!')



# /////////////////////////////grid created//////////////////////////////////////////////////
# /////////////////////////////Finding and placing container/////////////////////////////////
def placement(id,container_type,container_return_days,container_size):
    global area
    newinsert=True
    for i in area:
        if(container_type==area[i]['container_type']):
            newinsert=False
    
    if(newinsert==True):
        maxavailableareasize=0
        maxavailablearea=''
        is_space_available_flag=False
        for i in area:
            if area[i]['container_type']==' ' and area[i]['size']>maxavailableareasize :
                maxavailableareasize=area[i]['size']
                maxavailablearea=i
                is_space_available_flag=True
        if(is_space_available_flag==False):
            print('no more space left')
            return 0
        area[maxavailablearea]['container_type']=container_type
        placement(id,container_type,container_return_days,container_size)
        return 0
    else:
        insert_into_yard(id,container_type,container_return_days,container_size)

#///////////////////////////////insertion logic///////////////////////////////////////////////// 

def insert_into_yard(id,container_type,container_return_days,container_size):
            global area
            port_area=''
            for i in area:
                if(area[i]['container_type']==container_type and area[i]['full']==False):
                    port_area=i
                    break
            shapee=np.shape(area[port_area]['shape'])
            final_placement=''
            zero_flag=False
            for lev in range(shapee[0]):
                for col in range(shapee[1]):
                    for row in range(shapee[2]):
                            # if(lev!=3):
                                # print(lev,col,row,'below:',area[port_area]['shape'][lev+1][col][row]['below_container_export_days'],area[port_area]['shape'][lev][col][row]['val'])
                            # code for placement of size 20 container
                            if (container_size==20):
                                if(lev!=shapee[0]-1 and (area[port_area]['shape'][lev][col][row]['container_size']==0 or area[port_area]['shape'][lev][col][row]['container_size']==20)):
#                                     if(lev!=3):
#                                         print('idharhe::',lev,col,row,area[port_area]['shape'][lev][col][row]['val'],'=',container_return_days,area[port_area]['shape'][lev+1][col][row]['below_container_export_days'],'=',area[port_area]['shape'][lev][col][row]['val'],zero_flag)
                                    if(area[port_area]['shape'][lev][col][row]['val']>=container_return_days and area[port_area]['shape'][lev+1][col][row]['below_container_export_days']>=area[port_area]['shape'][lev][col][row]['val']):
                                        i=0
                                        flag=True
                                        for level in range(shapee[0]):
                                            # print(area[port_area]['shape'][level][col][row]['val'])
                                            if(area[port_area]['shape'][level][col][row]['val']==0):
                                                i=level
                                                flag=False
                                                break
                                        if(flag==False):
                                            final_placement=(i,col,row)
                                            zero_flag=True
                                    elif(area[port_area]['shape'][lev][col][row]['val']==0 and zero_flag==False):
                                        # print('idharr:',lev,col,row,area[port_area]['shape'][lev][col][row]['val'],zero_flag)
                                        final_placement=(lev,col,row)
                                        zero_flag=True
                                    elif(area[port_area]['shape'][lev][col][row]['val']<container_return_days):
                                        pass
                            # code for placement of size 40 container
                            else:
                                if(lev!=shapee[0]-1 and ((area[port_area]['shape'][lev][col][row]['container_size']==0 and row!=shapee[2]-1) or (area[port_area]['shape'][lev][col][row]['container_size']==40 and row!=shapee[2]-1))):  
                                    if(area[port_area]['shape'][lev][col][row]['val']>=container_return_days and area[port_area]['shape'][lev][col][row+1]['val']>=container_return_days and area[port_area]['shape'][lev+1][col][row]['below_container_export_days']>=area[port_area]['shape'][lev][col][row]['val'] and area[port_area]['shape'][lev+1][col][row+1]['below_container_export_days']>=area[port_area]['shape'][lev][col][row+1]['val']):
                                        i=0
                                        flag=True
                                        for level in range(shapee[0]):
                                            # print(area[port_area]['shape'][level][col][row]['val'])
                                            if(area[port_area]['shape'][level][col][row]['val']==0 and area[port_area]['shape'][level][col][row+1]['val']==0):
                                                i=level
                                                flag=False
                                                break
                                        if(flag==False):
                                            final_placement=(i,col,row)
                                            zero_flag=True
                                    elif(area[port_area]['shape'][lev][col][row]['val']==0 and area[port_area]['shape'][lev][col][row+1]['val']==0 and zero_flag==False):
                                            # print('idharr:',lev,col,row,area[port_area]['shape'][lev][col][row]['val'],zero_flag)
                                            final_placement=(lev,col,row)
                                            zero_flag=True
                                    elif(area[port_area]['shape'][lev][col][row]['val']<container_return_days):
                                        pass
            if(final_placement==''):
                area[port_area]['full']=True
                placement(id,container_type,container_return_days,container_size)
                return 0
            else:
                if (container_size==20 and final_placement[0]+1!=shapee[0]):
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['val']=container_return_days
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['id']=id
                    area[port_area]['shape'][final_placement[0]+1][final_placement[1]][final_placement[2]]['below_container_export_days']=container_return_days
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['container_size']=container_size
                elif (container_size==20 and final_placement[0]==shapee[0]-1):
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['val']=container_return_days
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['id']=id
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['below_container_export_days']=container_return_days
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['container_size']=container_size
                elif(container_size==40 and final_placement[0]+1!=shapee[0]):
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['val']=container_return_days
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]+1]['val']=container_return_days
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['id']=id
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]+1]['id']=id
                    area[port_area]['shape'][final_placement[0]+1][final_placement[1]][final_placement[2]]['below_container_export_days']=container_return_days
                    area[port_area]['shape'][final_placement[0]+1][final_placement[1]][final_placement[2]+1]['below_container_export_days']=container_return_days
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['container_size']=container_size
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]+1]['container_size']=container_size
                else:
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['val']=container_return_days
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]+1]['val']=container_return_days
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['id']=id
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]+1]['id']=id
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['below_container_export_days']=container_return_days
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]+1]['below_container_export_days']=container_return_days
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['container_size']=container_size
                    area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]+1]['container_size']=container_size
                if(container_size==20 and len(str(final_placement[2]))==1):
                    list.append(str(port_area)+'0'+str(final_placement[2])+str(final_placement[1])+str(final_placement[0]))
                elif(container_size==20 and len(str(final_placement[2]))!=1):
                    list.append(str(port_area)+str(final_placement[2])+str(final_placement[1])+str(final_placement[0]))
                elif(container_size==40 and (len(str(final_placement[2]))==1 or final_placement[2]<9)):
                    list.append(str(port_area)+'0'+str(final_placement[2]+1)+str(final_placement[1])+str(final_placement[0]))
                else:
                    list.append(str(port_area)+str(final_placement[2]+1)+str(final_placement[1])+str(final_placement[0]))
                    
#///////////////////////////////insertion logic ends////////////////////////////////////////// 
# /////////////////////////////Finding and placing container ends////////////////////////////
# /////////////////////////////Displaying our array or containers////////////////////////////
def display():
    for i in area:
        print(i)
        print('container_type:',area[i]['container_type'],'size:',area[i]['size'],'full:',area[i]['full'])
        print()
        shapee=np.shape(area[i]['shape'])
        for lev in range(shapee[0]):
            print('Level',lev+1)
            for col in range(shapee[1]):
                for row in range(shapee[2]):
                    print('days:',area[i]['shape'][lev][col][row]['val'],' id:',area[i]['shape'][lev][col][row]['id'],' container size:',area[i]['shape'][lev][col][row]['container_size'],end=', ')
                print()
            print()
# /////////////////////////////Displaying our array or containers ends////////////////////////////
# ////////////////////////////////////////////creating grid/////////////////////////////////////////////

import pandas as pd
data = pd.read_csv("Yard locations.csv")
dict={}
loc = data['Location']
for i in loc:
    areaaa = i[0:1]
    row = int(i[1:3])
    col = ord(str(i[3:4]))-64
    lev = int(i[4:5])

    if (areaaa not in dict.keys()):
        dict[areaaa] = {'maxrow': row,'maxcol': col,'maxlev':lev}
    else:
        if (dict[areaaa]['maxrow'] < row):
            dict[areaaa]['maxrow'] = row
        if (dict[areaaa]['maxcol'] < col):
            dict[areaaa]['maxcol'] = col
        if (dict[areaaa]['maxlev'] < lev):
            dict[areaaa]['maxlev'] = lev

# create_grid('A',4,4,6)
# create_grid('B',4,4,6)
# display()
for i in dict:
#              name,  level  ,    col    ,    row
    create_grid(i,dict[i]['maxlev'],dict[i]['maxcol'],dict[i]['maxrow'])

df = pd.read_csv('Predicted_Data.csv')
list=[]
for i in range(df.shape[0]):
    x1 = datetime.strptime(df['Out_Time'][i], '%Y-%m-%d %H:%M:%S')
    D=Milli(x1)
    placement(str(df['CON_NUM'][i]),str(df['STATUS'][i]),int(D),int(df['CON_SIZE'][i]))
    print(i,'Number of set inserted!!')
display()

# x1 = datetime.strptime(df['Out_Time'][0],'%Y-%m-%d %H:%M:%S')
# D=Milli(x1)
# placement(str(df['CON_NUM'][0]),str(df['STATUS'][0]),int(D),int(df['CON_SIZE'][0]))
# x1 = datetime.strptime(df['Out_Time'][3],'%Y-%m-%d %H:%M:%S')
# D=Milli(x1)
# placement(str(df['CON_NUM'][3]),str(df['STATUS'][3]),int(D),int(df['CON_SIZE'][3]))
print(list)

# placement('001','Empty',5,20)
# display()
# ///////////////////////////////////some examples for entry of containers ends//////////////////////////////

# basic description:
#  by running the code you will see placement of some containers.
#  if size is 40 than 2 index is filled for one container while for 20 only 1 index is filled
#  display will be as follows: Name of area-->info of area-->level(height index)-->row and col(row and col index)|
#                                                          /\                                                    |
#                                                          |                                                     \/
#                                                          |<-----------------------------------------------------
# Out:
# grid created!
# grid created!
# grid created!
# grid created!
# grid created!
# grid created!
# grid created!
# grid created!
# grid created!
# grid created!
# grid created!
# grid created!
# 0 3
# used 1!
# 0 Number of set inserted!!
# 1 3
# used 1!
# 1 Number of set inserted!!
# 2 3
# used 4!
# 2 Number of set inserted!!
# 0 3
# used 3!
# 3 Number of set inserted!!
# 0 4
# used 1!
# 4 Number of set inserted!!
# 1 4
# used 1!
# 5 Number of set inserted!!
# 2 4
# used 1!
# 6 Number of set inserted!!
# 3 4
# used 4!
# 7 Number of set inserted!!
# 0 4
# used 1!
# 8 Number of set inserted!!
# 1 4
# used 1!
# 9 Number of set inserted!!
# 2 4
# used 1!
# 10 Number of set inserted!!
# 0 4
# used 1!
# 11 Number of set inserted!!
# 1 4
# used 1!
# 12 Number of set inserted!!
# 2 4
# used 1!
# 13 Number of set inserted!!
# 3 4
# used 4!
# 14 Number of set inserted!!
# 0 4
# used 1!
# 15 Number of set inserted!!
# 1 4
# used 1!
# 16 Number of set inserted!!
# 2 4
# used 1!
# 17 Number of set inserted!!
# 0 4
# used 1!
# 18 Number of set inserted!!
# 1 4
# used 1!
# 19 Number of set inserted!!
# 2 4
# used 1!
# 20 Number of set inserted!!
# 3 4
# used 4!
# 21 Number of set inserted!!
# 0 3
# used 1!
# 22 Number of set inserted!!
# 1 3
# used 1!
# 23 Number of set inserted!!
# 0 4
# used 3!
# 24 Number of set inserted!!
# 1 4
# used 3!
# 25 Number of set inserted!!
# 2 4
# used 3!
# 26 Number of set inserted!!
# 1 3
# used 3!
# 27 Number of set inserted!!
# 0 3
# used 3!
# 28 Number of set inserted!!
# 1 3
# used 3!
# 29 Number of set inserted!!
# 2 3
# used 4!
# 30 Number of set inserted!!
# 0 3
# used 3!
# 31 Number of set inserted!!
# 1 3
# used 3!
# 32 Number of set inserted!!
# 0 4
# used 3!
# 33 Number of set inserted!!
# 2 3
# used 4!
# 34 Number of set inserted!!
# 0 3
# used 3!
# 35 Number of set inserted!!
# 1 3
# used 3!
# 36 Number of set inserted!!
# 2 3
# used 4!
# 37 Number of set inserted!!
# 0 3
# used 3!
# 38 Number of set inserted!!
# 1 4
# used 3!
# 39 Number of set inserted!!
# 1 3
# used 3!
# 40 Number of set inserted!!
# 2 3
# used 4!
# 41 Number of set inserted!!
# 0 3
# used 3!
# 42 Number of set inserted!!
# 1 3
# used 3!
# 43 Number of set inserted!!
# 2 3
# used 4!
# 44 Number of set inserted!!
# 0 3
# used 3!
# 45 Number of set inserted!!
# 1 3
# used 3!
# 46 Number of set inserted!!
# 2 4
# used 3!
# 47 Number of set inserted!!
# 2 3
# used 4!
# 48 Number of set inserted!!
# 2 3
# used 4!
# 49 Number of set inserted!!
# 0 3
# used 3!
# 50 Number of set inserted!!
# 1 3
# used 3!
# 51 Number of set inserted!!
# 0 3
# used 3!
# 52 Number of set inserted!!
# 0 3
# used 3!
# 53 Number of set inserted!!
# 0 3
# used 3!
# 54 Number of set inserted!!
# 0 4
# used 1!
# 55 Number of set inserted!!
# 0 4
# used 1!
# 56 Number of set inserted!!
# 0 3
# used 3!
# 57 Number of set inserted!!
# 1 3
# used 3!
# 58 Number of set inserted!!
# 0 3
# used 3!
# 59 Number of set inserted!!
# 1 3
# used 3!
# 60 Number of set inserted!!
# 0 3
# used 3!
# 61 Number of set inserted!!
# 0 3
# used 3!
# 62 Number of set inserted!!
# 0 3
# used 3!
# 63 Number of set inserted!!
# 0 3
# used 3!
# 64 Number of set inserted!!
# 1 3
# used 3!
# 65 Number of set inserted!!
# 0 3
# used 3!
# 66 Number of set inserted!!
# 0 3
# used 3!
# 67 Number of set inserted!!
# 0 3
# used 3!
# 68 Number of set inserted!!
# 0 3
# used 3!
# 69 Number of set inserted!!
# 0 3
# used 3!
# 70 Number of set inserted!!
# 0 3
# used 3!
# 71 Number of set inserted!!
# 1 3
# used 3!
# 72 Number of set inserted!!
# 0 3
# used 1!
# 73 Number of set inserted!!
# 0 3
# used 3!
# 74 Number of set inserted!!
# 1 3
# used 3!
# 75 Number of set inserted!!
# 2 3
# used 4!
# 76 Number of set inserted!!
# 0 3
# used 3!
# 77 Number of set inserted!!
# 0 3
# used 3!
# 78 Number of set inserted!!
# 0 3
# used 1!
# 79 Number of set inserted!!
# 0 3
# used 1!
# 80 Number of set inserted!!
# 0 3
# used 3!
# 81 Number of set inserted!!
# 1 3
# used 3!
# 82 Number of set inserted!!
# 0 3
# used 3!
# 83 Number of set inserted!!
# 3 4
# used 4!
# 84 Number of set inserted!!
# 2 3
# used 4!
# 85 Number of set inserted!!
# 1 4
# used 1!
# 86 Number of set inserted!!
# 2 4
# used 1!
# 87 Number of set inserted!!
# 3 4
# used 4!
# 88 Number of set inserted!!
# 1 4
# used 1!
# 89 Number of set inserted!!
# 2 4
# used 1!
# 90 Number of set inserted!!
# 3 4
# used 4!
# 91 Number of set inserted!!
# 0 4
# used 1!
# 92 Number of set inserted!!
# 1 4
# used 1!
# 93 Number of set inserted!!
# 2 4
# used 1!
# 94 Number of set inserted!!
# 0 4
# used 1!
# 95 Number of set inserted!!
# 1 4
# used 1!
# 96 Number of set inserted!!
# 2 4
# used 1!
# 97 Number of set inserted!!
# 3 4
# used 4!
# 98 Number of set inserted!!
# 0 4
# used 1!
# 99 Number of set inserted!!
# 1 4
# used 1!
# 100 Number of set inserted!!
# 2 4
# used 1!
# 101 Number of set inserted!!
# 0 4
# used 1!
# 102 Number of set inserted!!
# 1 4
# used 1!
# 103 Number of set inserted!!
# 2 4
# used 1!
# 104 Number of set inserted!!
# 3 4
# used 4!
# 105 Number of set inserted!!
# 0 4
# used 1!
# 106 Number of set inserted!!
# 1 4
# used 1!
# 107 Number of set inserted!!
# 2 4
# used 1!
# 108 Number of set inserted!!
# 0 4
# used 1!
# 109 Number of set inserted!!
# 1 4
# used 1!
# 110 Number of set inserted!!
# 2 4
# used 1!
# 111 Number of set inserted!!
# 3 4
# used 4!
# 112 Number of set inserted!!
# 0 4
# used 1!
# 113 Number of set inserted!!
# 1 4
# used 1!
# 114 Number of set inserted!!
# 2 4
# used 1!
# 115 Number of set inserted!!
# 0 4
# used 1!
# 116 Number of set inserted!!
# 1 4
# used 1!
# 117 Number of set inserted!!
# 2 4
# used 1!
# 118 Number of set inserted!!
# 3 4
# used 4!
# 119 Number of set inserted!!
# 0 4
# used 1!
# 120 Number of set inserted!!
# 1 4
# used 1!
# 121 Number of set inserted!!
# 2 4
# used 1!
# 122 Number of set inserted!!
# 0 4
# used 1!
# 123 Number of set inserted!!
# 1 4
# used 1!
# 124 Number of set inserted!!
# 2 4
# used 1!
# 125 Number of set inserted!!
# 3 4
# used 4!
# 126 Number of set inserted!!
# 0 4
# used 1!
# 127 Number of set inserted!!
# 1 4
# used 1!
# 128 Number of set inserted!!
# 2 4
# used 1!
# 129 Number of set inserted!!
# 0 4
# used 1!
# 130 Number of set inserted!!
# 1 4
# used 1!
# 131 Number of set inserted!!
# 2 4
# used 1!
# 132 Number of set inserted!!
# 3 4
# used 4!
# 133 Number of set inserted!!
# 0 4
# used 1!
# 134 Number of set inserted!!
# 1 4
# used 1!
# 135 Number of set inserted!!
# 2 4
# used 1!
# 136 Number of set inserted!!
# 0 4
# used 1!
# 137 Number of set inserted!!
# 1 4
# used 1!
# 138 Number of set inserted!!
# 2 4
# used 1!
# 139 Number of set inserted!!
# 3 4
# used 4!
# 140 Number of set inserted!!
# 0 4
# used 1!
# 141 Number of set inserted!!
# 1 4
# used 1!
# 142 Number of set inserted!!
# 2 4
# used 1!
# 143 Number of set inserted!!
# 0 4
# used 1!
# 144 Number of set inserted!!
# 1 4
# used 1!
# 145 Number of set inserted!!
# 2 4
# used 1!
# 146 Number of set inserted!!
# 3 4
# used 4!
# ['J0000', 'J0001', 'J0002', 'J0200', 'A0000', 'A0001', 'A0002', 'A0003', 'A0100', 'A0101', 'A0102', 'A0200', 'A0201', 'A0202', 'A0203', 'A0300', 'A0301', 'A0302', 'A0400', 'A0401', 'A0402', 'A0403', 'J0300', 'J0301', 'A0600', 'A0601', 'A0602', 'J0201', 'J0500', 'J0501', 'J0502', 'J0700', 'J0701', 'A0800', 'J0702', 'J0900', 'J0901', 'J0902', 'J1100', 'A0801', 'J1101', 'J1102', 'J1300', 'J1301', 'J1302', 'J1500', 'J1501', 'A0802', 'J1502', 'J0302', 'J1700', 'J1701', 'J1900', 'J2100', 'J2300', 'A0900', 'A1000', 'J2500', 'J2501', 'J2700', 'J2701', 'J2900', 'J3100', 'J3300', 'J3500', 'J3501', 'J3700', 'J3900', 'J4100', 'J4300', 'J4500', 'J4700', 'J4701', 'J4800', 'J5000', 'J5001', 'J5002', 'J5200', 'J5400', 'J5500', 'J5600', 'J5800', 'J5801', 'J0110', 'A0803', 'J5802', 'A1001', 'A1002', 'A1003', 'A0901', 'A0902', 'A0903', 'A1100', 'A1101', 'A1102', 'A1200', 'A1201', 'A1202', 'A1203', 'A1300', 'A1301', 'A1302', 'A1400', 'A1401', 'A1402', 'A1403', 'A1500', 'A1501', 'A1502', 'A1600', 'A1601', 'A1602', 'A1603', 'A1700', 'A1701', 'A1702', 'A1800', 'A1801', 'A1802', 'A1803', 'A1900', 'A1901', 'A1902', 'A2000', 'A2001', 'A2002', 'A2003', 'A2100', 'A2101', 'A2102', 'A2200', 'A2201', 'A2202', 'A2203', 'A2300', 'A2301', 'A2302', 'A2400', 'A2401', 'A2402', 'A2403', 'A2500', 'A2501', 'A2502', 'A2600', 'A2601', 'A2602']
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In [93], line 219
#     217     x1 = datetime.strptime(df['Out_Time'][i], '%Y-%m-%d %H:%M:%S')
#     218     D=Milli(x1)
# --> 219     placement(str(df['CON_NUM'][i]),str(df['STATUS'][i]),int(D),int(df['CON_SIZE'][i]))
#     220     print(i,'Number of set inserted!!')
#     221 display()
#
# Cell In [93], line 57, in placement(id, container_type, container_return_days, container_size)
#      55     return 0
#      56 else:
# ---> 57     insert_into_yard(id,container_type,container_return_days,container_size)
#
# Cell In [93], line 151, in insert_into_yard(id, container_type, container_return_days, container_size)
#     149 print('used 4!')
#     150 area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['val']=container_return_days
# --> 151 area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]+1]['val']=container_return_days
#     152 area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]]['id']=id
#     153 area[port_area]['shape'][final_placement[0]][final_placement[1]][final_placement[2]+1]['id']=id
#
# IndexError: list index out of range

# %%
x1 = datetime.strptime(df['Out_Time'][0],'%Y-%m-%d %H:%M:%S')

# %%
print(x1)
# Out:
# 2021-06-24 17:02:53

# %%
def Milli(X):
    given_date_time = X
    epoch = datetime(1970, 1, 1)
    time_difference = given_date_time - epoch
    total_seconds = time_difference.total_seconds()
    milliseconds = int(total_seconds * 1000)
    return milliseconds
def Date_Time(X):
    seconds = X / 1000
    date_time = datetime.fromtimestamp(seconds)
    date_time1= date_time.strftime('%d-%m-%Y %H:%M:%S')
    return date_time1

# %%
x=Milli(x1)
x
# Out:
# 1624554173000

# %%
Date_Time(x)
# Out:
# '24-06-2021 22:32:53'

# %%
a=10
list=[]

# %%
list.append(a)
list
# Out:
# [10, 10, 10, 10, 10, 10, 10, 10]
